# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import display

# Load data
data = pd.read_csv('/content/newlandingpage.csv')

# Display data structure
data_info = pd.DataFrame({
    'Total Rows': [data.shape[0]],
    'Total Columns': [data.shape[1]]
})
display(data_info)

# Display first few rows
display(data.head())

# Display column names
column_df = pd.DataFrame({'Column Names': data.columns})
display(column_df)

# Display missing values
missing_values = pd.DataFrame(data.isnull().sum(), columns=['Missing Values'])
display(missing_values)
# Out:
#    Total Rows  Total Columns
# 0      100000             13
#   Session primary channel group (Default Channel Group)  \
# 0                                             Direct
# 1                                              Email
# 2                                     Organic Search
# 3                                     Organic Search
# 4                                             Direct
#
#   Landing page + query string  Sessions  Engaged sessions  Engagement rate  \
# 0     /yeokens/dairy-go-round    396305            145355         0.366776
# 1     /yeokens/dairy-go-round    160528             60014         0.373854
# 2     /yeokens/dairy-go-round    144802             65245         0.450581
# 3            /yeokens/sign-in    125047            119306         0.954089
# 4                           /    115901            106669         0.920346
#
#    Bounce rate  Average session duration  Average engagement time per session  \
# ...

# %%
top10_landing = top10_landing.reset_index(drop=True)

# Show Top 10 landing page data as a table
display(top10_landing[['Landing page + query string', 'Sessions', 'Engagement rate (%)', 'Bounce rate (%)']])

x = np.arange(len(top10_landing['Landing page + query string']))
fig, ax = plt.subplots(figsize=(12,6))

bars1 = ax.bar(x, top10_landing['Engagement rate (%)'], label='Engagement Rate', color='steelblue')
bars2 = ax.bar(x, top10_landing['Bounce rate (%)'], bottom=top10_landing['Engagement rate (%)'], label='Bounce Rate', color='firebrick')

# Annotations
for idx in range(len(top10_landing)):
    ax.text(idx, top10_landing['Engagement rate (%)'][idx] / 2, f"{top10_landing['Engagement rate (%)'][idx]:.1f}%", ha='center', color='white', fontsize=8)
    ax.text(idx, top10_landing['Engagement rate (%)'][idx] + (top10_landing['Bounce rate (%)'][idx] / 2), f"{top10_landing['Bounce rate (%)'][idx]:.1f}%", ha='center', color='white', fontsize=8)

ax.set_xticks(x)
ax.set_xticklabels(top10_landing['Landing page + query string'], rotation=45, ha='right')
ax.set_ylabel('Rate')
ax.set_title('Stacked Engagement Rate and Bounce Rate by Landing Page')
ax.legend(loc='upper right')
plt.tight_layout()
plt.show()
# Out:
#   Landing page + query string  Sessions  Engagement rate (%)  Bounce rate (%)
# 0     /yeokens/dairy-go-round    765555            47.174248        52.825752
# 1                           /    264126            75.350261        24.649739
# 2            /yeokens/sign-in    207809            75.144712        24.855288
# 3        /yeokens/get-banking    158735            48.187853        51.812147
# 4            /yeokens/welcome     97895            70.281466        29.718534
# 5                /yeokens/hub     77853            60.989568        39.010432
# 6                    /yeokens     62874            76.505093        23.494907
# 7                   (not set)     59464             0.817887        99.182113
# 8               /yeokens/play     50912            71.699304        28.300696
# 9        /yeokens/type-a-code     49291            36.767706        63.232294
